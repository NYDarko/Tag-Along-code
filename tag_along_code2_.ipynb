# %% [markdown]
# <a href="https://colab.research.google.com/github/NYDarko/Tag-Along-code/blob/main/tag_along_code2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("/content/drive/MyDrive/Projects/energydata_complete.csv")

# %%
df.head() 
#rename columns

column_names = {'T1':'Kitchen_Temp','RH_1': 'kitchen_humd', 'T2':'lr_temp', 'RH_2':'lr_humd%', 'T3': 'laundry_temp'}
df = df.rename(columns = column_names)

df
# Out:
#                   date  Appliances  lights  Kitchen_Temp  kitchen_humd  \
# 0  2016-01-11 17:00:00          60      30         19.89     47.596667
# 1  2016-01-11 17:10:00          60      30         19.89     46.693333
# 2  2016-01-11 17:20:00          50      30         19.89     46.300000
# 3  2016-01-11 17:30:00          50      40         19.89     46.066667
# 4  2016-01-11 17:40:00          60      40         19.89     46.333333
#
#    lr_temp   lr_humd%  laundry_temp       RH_3         T4  ...         T9  \
# 0     19.2  44.790000         19.79  44.730000  19.000000  ...  17.033333
# 1     19.2  44.722500         19.79  44.790000  19.000000  ...  17.066667
# 2     19.2  44.626667         19.79  44.933333  18.926667  ...  17.000000
# 3     19.2  44.590000         19.79  45.000000  18.890000  ...  17.000000
# 4     19.2  44.530000         19.79  45.000000  18.890000  ...  17.000000
#
#     RH_9     T_out  Press_mm_hg  RH_out  Windspeed  Visibility  Tdewpoint  \
# ...

# %%
#create model
model = LinearRegression()

#Fit the model to the data
x = df['lr_temp'].values.reshape(-1,1)
y = df['T6'].values.reshape(-1,1)

model.fit(x,y)

sns.regplot(x, y, fit_reg=True)

# Add a title and labels
plt.title('living room temp by temp outside building')
plt.xlabel('LR TEMP')
plt.ylabel('OB TEMP')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'OB TEMP')

# %%
#r^2 value
Y_predict = model.predict(y)
plt.plot(x,y)
plt.plot(x,Y_predict, color = 'red')
plt.show()
from sklearn.metrics import r2_score
r2 = r2_score(y,Y_predict)
print(round(r2,2))
# Out:
# -21.13

# %%
#df.drop('date', axis = 1, inplace = True) 
df.drop('lights', axis = 1, inplace = True)

# %%
#Firstly, we normalise our dataset to a common scale using the min max scaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
normalised_df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
target_variable = normalised_df['Appliances']
# Out:
#        Appliances  Kitchen_Temp  kitchen_humd   lr_temp  lr_humd%  \
# 0        0.046729      0.327350      0.566187  0.225345  0.684038
# 1        0.046729      0.327350      0.541326  0.225345  0.682140
# 2        0.037383      0.327350      0.530502  0.225345  0.679445
# 3        0.037383      0.327350      0.524080  0.225345  0.678414
# 4        0.046729      0.327350      0.531419  0.225345  0.676727
# ...           ...           ...           ...       ...       ...
# 19730    0.084112      0.926786      0.537657  0.711655  0.606309
# 19731    0.074766      0.919747      0.536006  0.701769  0.607836
# 19732    0.242991      0.919747      0.538666  0.692651  0.627198
# 19733    0.383178      0.919747      0.549491  0.677054  0.634717
# 19734    0.392523      0.919747      0.538758  0.666171  0.632902
#
#        laundry_temp      RH_3        T4      RH_4        T5  ...        T9  \
# 0          0.215188  0.746066  0.351351  0.764262  0.175506  ...  0.223032
# ...
